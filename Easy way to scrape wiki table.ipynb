# %% [markdown]
# # Easy way to scrape wiki table

# %%
import pandas as pd

url = "https://en.wikipedia.org/wiki/List_of_female_billionaires"


tables = pd.read_html(url)


df = tables[0]

df
# Out:
#    No.                          Name  Image                Birth date  \
# 0    1  Françoise Bettencourt Meyers    NaN                  (age 70)
# 1    2                  Alice Walton    NaN                  (age 73)
# 2    3               MacKenzie Scott    NaN                  (age 53)
# 3    4                    Julia Koch    NaN                  (age 61)
# 4    5                Miriam Adelson    NaN                  (age 77)
# 5    6               Jacqueline Mars    NaN                  (age 83)
# 6    7                   Yang Huiyan    NaN                  (age 42)
# 7    8               Susanne Klatten    NaN                  (age 61)
# 8    9                 Gina Rinehart    NaN                  (age 69)
# 9   10                 Iris Fontbona    NaN  1942 or 1943 (age 80–81)
#
#    Net worth US$(billions)             Citizenship                   Source  \
# 0                     73.6                  France                  L'Oréal
# ...
